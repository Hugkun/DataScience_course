# %% [markdown]
# # 個人医療保険料予測
#
# ここからは、ノートブック1で学んだ内容を活かして取り組んでみましょう！

# %% [markdown]
# - レストランのチップ額予測モデルを参考に、個人の医療保険料予測を行ってみましょう。
# - データセットに関してはGithubを参考にしてみましょう。
#   - Github → https://gist.github.com/meperezcuello/82a9f1c1c473d6585e750ad2e3c05a41

# %% [markdown]
# ## **個人医療保険料予測を行います**

# %% [markdown]
# ### ライブラリのインストール

# %%
# matplotlib日本語対応ライブラリのインストール

# %% [markdown]
# ### GoogleDrive の Mount

# %%
# drive.mount()を使用してGoogleDriveをMount

# %%
# os.chdir()を使用してカレントディレクトリを変更。作成したショーットカット名を使ってパスを指定します。

# %% [markdown]
# ### ライブラリのimport

# %% [markdown]
# ### 定数の定義
# - データファイルパスを定義します

# %%
# データファイルパス定義
MEDICAL_COST_CSV = "./data/medical_cost_customized.csv"

# %% [markdown]
# ### 個人医療保険料予測のデータセットを読み込みます

# %%
# データセットを読み込み

# %% [markdown]
# ### **読み込んだDataFrameの中身を確認してみましょう**

# %% [markdown]
# #### 先頭５行のデータをざっと眺めてみましょう

# %%
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# - (考察を記載してみましょう)

# %%
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# - (考察を記載してみましょう)

# %%
# Out:
# smoker
# no     1061
# yes     273
# Name: count, dtype: int64

# %% [markdown]
# - (考察を記載してみましょう)

# %%
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# - (考察を記載してみましょう)

# %% [markdown]
# ### **次に行数、列数、データ型、欠損値を確認します**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1334 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# ### 考察
# - (考察を記載してみましょう)

# %% [markdown]
# ### **基本統計量を確認します**

# %%
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## 考察
# - (考察を記載してみましょう)

# %% [markdown]
# ### **欠損値の対策**

# %%
# 欠損値の数を確認
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      4
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# - (考察を記載してみましょう)

# %%
# 欠損値を持つ行を確認
# Out:
#      age     sex     bmi  children smoker     region      charges
# 32    19  female  28.600         5    NaN  southwest   4687.79700
# 347   46    male  33.345         1    NaN  northeast   8334.45755
# 429   27  female  30.400         3    NaN  northwest  18804.75240
# 827   36    male  28.025         1    NaN  northeast  20773.62775

# %% [markdown]
# - (考察を記載してみましょう)

# %%
# 欠損値の削除
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1334 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1334 non-null   int64
#  1   sex       1334 non-null   object
#  2   bmi       1334 non-null   float64
#  3   children  1334 non-null   int64
#  4   smoker    1334 non-null   object
#  5   region    1334 non-null   object
#  6   charges   1334 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.4+ KB

# %% [markdown]
# ### **カテゴリカル変数の対策**

# %%
# Out:
# sex
# 1    674
# 0    660
# Name: count, dtype: int64
# smoker
# 0    1061
# 1     273
# Name: count, dtype: int64
# region
# 2    364
# 1    324
# 3    324
# 0    322
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 1334 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1334 non-null   int64
#  1   sex       1334 non-null   category
#  2   bmi       1334 non-null   float64
#  3   children  1334 non-null   int64
#  4   smoker    1334 non-null   category
#  5   region    1334 non-null   category
#  6   charges   1334 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 56.5 KB

# %% [markdown]
# ### 相関係数の表示

# %% [markdown]
# ### 考察
# - (考察を記載してみましょう)

# %% [markdown]
# ### **回帰モデルを作ってみましょう！**（LinearRegression）

# %%
# 説明変数と目的変数に分ける



# 訓練データとテストデータに分割する

# %%
# LinearRegressionで学習させる
# Out:
# LinearRegression()

# %% [markdown]
# ### **エラーレートと決定係数を使ってモデルを評価します**

# %%
# Out:
# 学習時スコア(train score)
# 　平均絶対誤差:  4037.6275343014368
# 　平均二乗誤差:  34783334.168543726
# 　二乗平均平方根誤差:  5897.7397508319855
# 　決定係数R^2:  0.7654786758573293
# テストスコア(test score)
# 　平均絶対誤差:  4316.284017268299
# 　平均二乗誤差:  40801708.47263143
# 　二乗平均平方根誤差:  6387.621503551336
# 　決定係数R^2:  0.7153592693840074

# %% [markdown]
# ### 考察
# - (考察を２つ記載してみましょう)

# %% [markdown]
# ### **残差を可視化してモデルを評価してみましょう！**

# %% [markdown]
# ### 考察
# - (考察を２つ記載してみましょう)

# %% [markdown]
# ### **別の回帰モデルを試してみましょう！**

# %%
# 学習する
# Out:
# RandomForestRegressor(max_depth=3)

# %% [markdown]
# ### **エラーレートと決定係数を使ってモデルの評価を行います**

# %%
# Out:
# 学習時スコア(train score)
# 　平均絶対誤差:  2533.904049705871
# 　平均二乗誤差:  19035215.32591678
# 　二乗平均平方根誤差:  4362.936548463292
# 　決定係数R^2:  0.8716579646464133
# テストスコア(test score)
# 　平均絶対誤差:  2680.1252544725103
# 　平均二乗誤差:  22319350.604014046
# 　二乗平均平方根誤差:  4724.335996096599
# 　決定係数R^2:  0.844295827292074

# %% [markdown]
# ### 考察
# - (考察を２つ記載してみましょう)

# %% [markdown]
# ### **今回も残差を可視化してモデルを評価しましょう！**

# %% [markdown]
# ### 考察
# - (考察を２つ記載してみましょう)

# %% [markdown]
# ### **ボーナス：さらなる精度改善に挑戦してみましょう！**
# 💪 ネットを検索してこれまでとは違うモデルやパラメータ、前処理等を行い、精度改善にトライしてみましょう！

# %%
# Out:
# 学習時スコア(train score)
# 　平均絶対誤差:  2058.231930635987
# 　平均二乗誤差:  14217622.98746444
# 　二乗平均平方根誤差:  3770.626338881173
# 　決定係数R^2:  0.9041398460243977
# テストスコア(test score)
# 　平均絶対誤差:  2630.7826999358444
# 　平均二乗誤差:  23141905.587078616
# 　二乗平均平方根誤差:  4810.603453526243
# 　決定係数R^2:  0.8385575222034923

# %% [markdown]
# ### 考察
# - (考察を記載してみましょう)

# %% [markdown]
# ---
# ---
# ---
# ---
# ---
